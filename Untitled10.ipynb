# %% [markdown]
# <a href="https://colab.research.google.com/github/jhansijanu564-lgtm/Data-Science-Project/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
text = "This is\t a\n test"
split_text = re.split(r'\s+',text)
print(split_text)
# Out:
# ['This', 'is', 'a', 'test']
