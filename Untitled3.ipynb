# %%
import pandas as pd
student_data = {
    "Roll_No": [101, 102, 103],
    "Name": ["Harshi", "Prathibha", "Shanvika"],
    "Department": ["IT", "IT", "CSE"], # Corrected length from 4 to 3
    "Percentage": [95, 90, 89]
}
course_data = {
    "course_ID": ["C101", "C102", "C103"],
    "course_name": ["python", "data science", "machine learning"],
    "credits": [4, 3, 4]
}
students_df = pd.DataFrame(student_data)
courses_df = pd.DataFrame(course_data)
print("Students DataFrame:")
display(students_df)
print("\nCourses DataFrame:")
display(courses_df)
# Out:
# Students DataFrame:
#    Roll_No       Name Department  Percentage
# 0      101     Harshi         IT          95
# 1      102  Prathibha         IT          90
# 2      103   Shanvika        CSE          89
# Courses DataFrame:
#   course_ID       course_name  credits
# 0      C101            python        4
# 1      C102      data science        3
# 2      C103  machine learning        4

# %%
import pandas as pd
excel_data = {
    "students": students_df,
    "courses": courses_df
}
print("Available_sheets:")
print(excel_data.keys())
print("\n student_sheet:")
print(excel_data["students"])
print("\n course sheet:")
print(excel_data["courses"])
# Out:
# Available_sheets:
# dict_keys(['students', 'courses'])
#
#  student_sheet:
#    Roll_No       Name Department  Percentage
# 0      101     Harshi         IT          95
# 1      102  Prathibha         IT          90
# 2      103   Shanvika        CSE          89
#
#  course sheet:
#   course_ID       course_name  credits
# 0      C101            python        4
# 1      C102      data science        3
# 2      C103  machine learning        4

# %%
import pandas as pd
from io import StringIO
csv_url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
csv_df = pd.read_csv(csv_url)
print("csv Data:")
csv_df.to_csv("iris_output.csv", index=False)
print("\ncsv file written successfully")
# Out:
# csv Data:
#
# csv file written successfully

# %%
import pandas as pd
student_data={
    "Roll_No":[101,102,103,104],
    "Name":["Harshi","Prathibha","Shanvika","Abhi"],
    "Department":["IT","IT","CSE","ECE"],
    "Percentage":[96,95,80,90]
}
student_df = pd.DataFrame(student_data)
student_df.to_csv(
    "student_output.txt",
    sep="\t",
    index=False
)
task_df=pd.read_csv(
    "student_output.txt",
    sep="\t"
)
print("\n Tab_limited Data:")
print(task_df)
# Out:
#  Tab_limited Data:
#    Roll_No       Name Department  Percentage
# 0      101     Harshi         IT          96
# 1      102  Prathibha         IT          95
# 2      103   Shanvika        CSE          80
# 3      104       Abhi        ECE          90

# %%
import pandas as pd
JSON_string="""
[{"Roll_No":201,"Name":"HARSHI","Percentage":91},
{"Roll_No":202,"Name":"PRATHIBHA","Percentage":90}
]
"""
parsed_json_df = pd.read_json(JSON_string)
print("\nParsed JSON string:")
print(parsed_json_df)
student_df = parsed_json_df
student_df.to_excel(
    "students.xlsx",
    sheet_name="student Details",
    index=False
)
print("\nExcel Data (based on the DataFrame saved):")
print(student_df)
print("\nAll file operation completed successfully")
# Out:
# /tmp/ipykernel_2364/3042539381.py:7: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   parsed_json_df = pd.read_json(JSON_string)
# Parsed JSON string:
#    Roll_No       Name  Percentage
# 0      201     HARSHI          91
# 1      202  PRATHIBHA          90
#
# Excel Data (based on the DataFrame saved):
#    Roll_No       Name  Percentage
# 0      201     HARSHI          91
# 1      202  PRATHIBHA          90
#
# All file operation completed successfully
