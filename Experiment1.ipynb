# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv



"

df = pd.read_csv(url)

print("First five rows of the dataset:")
print(df.head())

print("\nDataset Information:")
df.info()

print("\nNumber of rows and columns:")
print(df.shape)
# Out:
#   File "/tmp/ipykernel_931/2703611234.py", line 3
#     url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv
#           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

df = pd.read_csv(url)

df.to_csv("iris_output.csv", index=False)

print("The dataset has been successfully written to iris_output.csv")
# Out:
# The dataset has been successfully written to iris_output.csv

# %%
import pandas as pd

data = """Roll-No\tName\tDepartment\tPercentage
101\tHarshi\tIT\t89
102\tPrathibha\tIT\t92
103\tGeetha\tCSE\t88
104\tSeetha\tECE\t85"""

with open("students.txt", "w") as f:
    f.write(data)

df = pd.read_csv("students.txt", sep="\t")
print("Student data:")
print(df)

df = pd.read_table("students.txt")
print(df)
# Out:
# Student data:
#    Roll-No       Name Department  Percentage
# 0      101     Harshi         IT          89
# 1      102  Prathibha         IT          92
# 2      103     Geetha        CSE          88
# 3      104     Seetha        ECE          85
#    Roll-No       Name Department  Percentage
# 0      101     Harshi         IT          89
# 1      102  Prathibha         IT          92
# 2      103     Geetha        CSE          88
# 3      104     Seetha        ECE          85

# %%
import pandas as pd
Student_data = {
    "Roll_No" : [101,102,103,104],
    "Name" : ["Harshi","Prathibha","Geetha","Seetha"],
    "Department" : ["IT","IT","CSE","ECE"],
    "Percentage" : [89,92,88,85]
}
df = pd.DataFrame(Student_data)
df.to_csv("students.csv", index=False)
print("Student data has been successfully written to students.csv")
# Out:
# Student data has been successfully written to students.csv
